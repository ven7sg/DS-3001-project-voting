# %% [markdown]
# <a href="https://colab.research.google.com/github/ven7sg/DS-3001-project-voting/blob/main/Project_3_va_voting_(Group_7).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/dianatuyen/DS-3001-project-voting.git
# Out:
# fatal: destination path 'DS-3001-project-voting' already exists and is not an empty directory.

# %%
# !pip3 install mapclassify

# %%
import geopandas as gpd
import mapclassify
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# Load data
#gdf_adoption = gpd.read_file('./DS-3001-project-voting/data/VirginiaAdoptionLines.shx') # Load Virginia shapefile for maps
gdf_county = gpd.read_file('./DS-3001-project-voting/VirginiaCounty_ClippedToShoreline.shx') # Load Virginia shapefile for maps
# Out:
# ERROR:fiona._env:./DS-3001-project-voting/VirginiaCounty_ClippedToShoreline.shx: No such file or directory
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/ogrext.pyx in fiona.ogrext.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: ./DS-3001-project-voting/VirginiaCounty_ClippedToShoreline.shx: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-9-589ac5d28af7> in <cell line: 3>()
#       1 # Load data
#       2 #gdf_adoption = gpd.read_file('./DS-3001-project-voting/data/VirginiaAdoptionLines.shx') # Load Virginia shapefile for maps
# ----> 3 gdf_county = gpd.read_file('./DS-3001-project-voting/VirginiaCounty_ClippedToShoreline.shx') # Load Virginia shapefile for maps
#
# ...

# %%
# Merge shapefile data and county adjacency data:
gdf['FIPS_left'] = pd.to_numeric(gdf['STCOFIPS'])
df = gdf.merge(cdf,left_on='FIPS_left',right_on='FIPS')  # merge county population and adjacency data into df
del gdf, cdf

# %%
vdf = pd.read_csv('./DS-3001-project-voting/data/voting_VA.csv') # Load historical voting data
cdf = pd.read_csv('./DS-3001-project-voting/data/county_adjacencies.csv') # Load county adjacency data and population data
# Summary information of dataframe (Tamera Fang)
vdf.describe()
cdf.describe()

# Missing values in:

# Remove unnecessary columns in vdf:
voting_cleaned = vdf.drop(columns=['Unnamed: 0', 'version', 'mode'])
# remove repeating columns (Diana)
unnecessary_columns = ['office', 'state', 'state_po', 'year'] # office bc all of them are US pres and state bc all are VA and year bc all are 2000
voting_cleaned.drop(unnecessary_columns, axis=1, inplace=True)
voting_cleaned.dropna(inplace=True)
voting_cleaned['party'] = voting_cleaned['party'].astype('category')
voting_cleaned
# Out:
#           county_name  county_fips       candidate       party  \
# 0            ACCOMACK        51001         AL GORE    DEMOCRAT
# 1            ACCOMACK        51001  GEORGE W. BUSH  REPUBLICAN
# 2            ACCOMACK        51001     RALPH NADER       GREEN
# 3            ACCOMACK        51001           OTHER       OTHER
# 4           ALBEMARLE        51003         AL GORE    DEMOCRAT
# ...               ...          ...             ...         ...
# 3731  WINCHESTER CITY        51840           OTHER       OTHER
# 3732  WINCHESTER CITY        51840           OTHER       OTHER
# 3733  WINCHESTER CITY        51840  DONALD J TRUMP  REPUBLICAN
# 3734  WINCHESTER CITY        51840  DONALD J TRUMP  REPUBLICAN
# 3735  WINCHESTER CITY        51840  DONALD J TRUMP  REPUBLICAN
#
#       candidatevotes  totalvotes
# 0               5092       11925
# 1               6352       11925
# 2                220       11925
# 3                261       11925
# 4              16255       36846
# ...

# %%
# cleaning county adjacencies(Diana):
county_adjacencies = cdf.drop_duplicates()
county_adjacencies
# Out:
#                County  Population2022   FIPS  District                   N1  \
# 0            Accomack           33191  51001         2       Northumberland
# 1           Albemarle          114534  51003         5  CharlottesvilleCity
# 2      AlexandriaCity          155525  51510         8              Fairfax
# 3           Alleghany           14835  51005         6                Craig
# 4              Amelia           13455  51007         5         PrinceEdward
# ..                ...             ...    ...       ...                  ...
# 128    WinchesterCity           27936  51840         6            Frederick
# 129              Wise           35421  51195         9                  Lee
# 130             Wythe           28111  51197         9                Bland
# 131              York           71341  51199         1           Gloucester
# 132  WilliamsburgCity           15920  51830         1             JamesCty
#
# ...
